# %%
import scanpy as sc
import sys
sys.path.append('/wsfish/glioblastoma/')
import FISHspace as sp

# %reload_ext autoreload
# %autoreload 2

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['pdf.fonttype'] = 42

# save figure with no pad
mpl.rcParams['savefig.pad_inches'] = 0
mpl.rcParams['savefig.bbox'] = 'tight'

# set axes width
mpl.rcParams['axes.linewidth'] = 0.2
mpl.rcParams['xtick.minor.pad'] = 0
mpl.rcParams['xtick.major.pad'] = 0
mpl.rcParams['ytick.minor.pad'] = 0
mpl.rcParams['ytick.major.pad'] = 0
mpl.rcParams['xtick.minor.width'] = 0.2
mpl.rcParams['xtick.major.width'] = 0.2
mpl.rcParams['ytick.minor.width'] = 0.2
mpl.rcParams['ytick.major.width'] = 0.2

# %%
WR_adata = sc.read_h5ad('../Fig2/GWlike_scfates.h5ad')

# %%
import pandas as pd

# %%
rename_dic = {
    'GW-like 5':'GW-like Endo.Ass.',
    'GW-like 2':'GW-like Periphery1',
    'GW-like 3':'GW-like Periphery2',
    'GW-like 1':'GW-like Periphery3',
    
    'GW-like 6':'GW-like HYPR2',
    'GW-like 8':'GW-like HYPR1',
    'GW-like 7':'GW-like OPC',
    'GW-like 4':'GW-like nIPC',
    
    'nIPC-RG-like':'RG-like',
    
 
}

WR_adata.obs['m-states3'] = pd.Categorical([rename_dic[m] if m in rename_dic else m for m in WR_adata.obs['m-states']])

# %%
rename_dic.values()
# Out:
# dict_values(['GW-like Endo.Ass.', 'GW-like Periphery1', 'GW-like Periphery2', 'GW-like Periphery3', 'GW-like HYPR2', 'GW-like HYPR1', 'GW-like OPC', 'GW-like nIPC', 'RG-like'])

# %%
palette = {
    'GW-like Endo.Ass.':'#2d55ff', 
    'GW-like Periphery1':'#93faa5', 
    'GW-like Periphery2':'#68c3a3', 
    'GW-like Periphery3':'#d5b8ff', 
    'GW-like HYPR1':'#e33d94', 
    'GW-like HYPR2': '#c44d56', 
    'GW-like OPC':'#ff9470', 
    'GW-like nIPC': '#f3e16b',
}

# %%
palette = {
    'GW-like Endo.Ass.':'#2d55ff', 
    'GW-like Periphery1':'#93faa5', 
    'GW-like Periphery2':'#68c3a3', 
    'GW-like Periphery3':'#d5b8ff', 
    'GW-like HYPR1':'#e33d94', 
    'GW-like HYPR2': '#c44d56', 
    'GW-like OPC':'#ff9470', 
    'GW-like nIPC': '#f3e16b',
}

palette_common = {
  
    'GW-like Endo.Ass.':'#CFA8D1', 
    'GW-like Periphery1':'#EDE8F3',
    'GW-like Periphery2':'#E2D8EA',
    'GW-like Periphery3':'#D6BEDD', 
    'GW-like HYPR1':'#C50F53', 
    'GW-like HYPR2': '#840034', 
    'GW-like OPC':'#A40447', 
    'GW-like nIPC': '#e43c96',
    
}

# %%
plt.figure(figsize=(5,5))
sc.pl.pca(
    WR_adata, 
    color=['m-states3'],
    palette=palette_common,
    s=20, 
    frameon=False,
    show=False,
)
plt.savefig('figures/WR_pca.png', dpi=300, transparent=True,)

# %%
scf.pl.graph(
    WR_adata,
    basis="pca",
    frameon=False,
    save='figures/scFate.png',
)
# Out:
# WARNING: saving figure to file figures/graphfigures/scFate.png

# %%
WR_adata.var
# Out:
#         Accession     Gene  n_cells  highly_variable     means  dispersions  \
# Gene
# ACKR3       ACKR3    ACKR3    23553            False  0.002237    -1.991970
# ADGRV1     ADGRV1   ADGRV1    92618            False  0.009237    -1.973027
# AHSP         AHSP     AHSP    68869            False  0.006953    -1.963939
# AIF1         AIF1     AIF1    41973            False  0.003927    -1.981845
# AKAP6       AKAP6    AKAP6   105831            False  0.010686    -1.998188
# ...           ...      ...      ...              ...       ...          ...
# ZFAND2A   ZFAND2A  ZFAND2A    62869            False  0.005954    -2.010663
# ZFAND3     ZFAND3   ZFAND3   122309            False  0.012368    -2.006610
# ZFHX4       ZFHX4    ZFHX4    23825            False  0.002188    -2.025100
# ZFPM2       ZFPM2    ZFPM2   122312            False  0.012788    -1.990045
# ZIC1         ZIC1     ZIC1    51098            False  0.005024    -1.958832
#
# ...

# %%
for c in [0,1,2,3,4]:
    print(c)
    c = str(c)
    scf.pl.trends(
        WR_adata,
        features=WR_adata.var_names[WR_adata.var.clusters==c],
        basis="pca",
        feature_cmap='PuRd', 
        pseudo_cmap = 'magma',
        show=False,
        n_features=20,
        save='figures/trendsfigures/graphfigures/{}.pdf'.format(c),
    )
    #plt.savefig('figures/trendsfigures/graphfigures/{}.pdf'.format(c), dpi=300,)
# Out:
# 0
# /home/alejandro/miniconda3/envs/py311/lib/python3.11/site-packages/scFates/plot/features.py:185: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   g = adata.obs.groupby("seg")
# /home/alejandro/miniconda3/envs/py311/lib/python3.11/site-packages/scFates/plot/features.py:480: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.871381   0.87103992 0.87093883 ... 0.18469172 0.18426911 0.18425649]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   adata_temp.obs.loc[
# 1
# ...

# %%
c = '2'
scf.pl.trends(
    WR_adata,
    features=WR_adata.var_names[WR_adata.var.clusters==c],
    basis="pca",
    feature_cmap='PuRd', 
    pseudo_cmap = 'magma',
    show=False,
    n_features=20,
    save='figures/trendsfigures/graphfigures/{}.png'.format(c),
)
# Out:
# /home/alejandro/miniconda3/envs/py311/lib/python3.11/site-packages/scFates/plot/features.py:185: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   g = adata.obs.groupby("seg")
# /home/alejandro/miniconda3/envs/py311/lib/python3.11/site-packages/scFates/plot/features.py:480: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.45376941 0.45266404 0.45233642 ... 0.82934228 0.82973683 0.82974861]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   adata_temp.obs.loc[
# [<Axes: >, <Axes: ylabel='Gene'>, <Axes: xlabel='PC1', ylabel='PC2'>]

# %%
for c in WR_adata.var["clusters"].unique():
    scf.pl.trends(
        WR_adata,
        features=WR_adata.var_names[WR_adata.var.clusters==c],
        basis="pca",
        feature_cmap='PuRd', 
        pseudo_cmap = 'magma',
        show=False,
        save='figures/graphfigures/{}.pdf'.format(c),
    )
# Out:
# /home/alejandro/miniconda3/envs/py311/lib/python3.11/site-packages/scFates/plot/features.py:185: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   g = adata.obs.groupby("seg")
# /home/alejandro/miniconda3/envs/py311/lib/python3.11/site-packages/scFates/plot/features.py:480: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.94007987 0.93743624 0.9366527  ... 0.22874805 0.2282875  0.22827374]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   adata_temp.obs.loc[
# ...

# %% [markdown]
# # Take a smaller sample for analysis

# %%
import scFates as scf
GW
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 import scFates as scf
# ----> 2 GW
#
# NameError: name 'GW' is not defined

# %%
#GW_mini = sc.pp.subsample(GW,n_obs=100000,copy=True)

# %%
GW_mini = GW

# %%
scf.tl.curve(GW_mini, Nodes=20,use_rep="X_pca",ndims_rep=2,epg_mu=.5)

# %%
scf.tl.root(GW_mini,'AQP4')

# %%
scf.tl.pseudotime(GW_mini,n_jobs=56,n_map=100,seed=42)

# %%
scf.tl.test_association(GW_mini, n_jobs=56)

# %%
scf.tl.test_association(GW_mini,reapply_filters=True,A_cut=.25)
scf.pl.test_association(GW_mini)

# %%
GW_mini.write_h5ad

# %%
GW_mini_export = GW_mini.copy()
#del GW_mini_export.uns['graph']
del GW_mini_export.uns['epg']
print('Copied')
GW_mini_export.write_h5ad('GWlike_scfates.h5ad')

# %%
scf.tl.fit(GW_mini,n_jobs=56)

# %%
scf.pl.single_trend(GW_mini_export,"VEGFA",basis="pca",color_exp="k", alpha_expr=0.1, size_expr=.01,fitted_linewidth=5,)

# %%
scf.pl.single_trend(GW_mini,"VEGFA",basis="pca",color_exp="k", alpha_expr=0.1, size_expr=.01,fitted_linewidth=5,)
scf.pl.single_trend(GW_mini,"VIM",basis="pca",color_exp="k", alpha_expr=0.1, size_expr=.01,fitted_linewidth=5,)
scf.pl.single_trend(GW_mini,"SERPINE1",basis="pca",color_exp="k", alpha_expr=0.1, size_expr=.01,fitted_linewidth=5,)
scf.pl.single_trend(GW_mini,"LGALS1",basis="pca",color_exp="k", alpha_expr=0.1, size_expr=.01,fitted_linewidth=5,)
scf.pl.single_trend(GW_mini,"AQP4",basis="pca",color_exp="k", alpha_expr=0.1, size_expr=.01,fitted_linewidth=5,)

# %%
scf.pl.single_trend(GW_mini,"FOXG1",basis="pca",color_exp="k", alpha_expr=0.1, size_expr=.01,fitted_linewidth=5,)

# %%
#scf.pl.single_trend(GW_mini,"ARX",basis="pca",color_exp="k", alpha_expr=0.1, size_expr=.01,fitted_linewidth=5,)

# %%
scf.pl.single_trend(GW_mini,"SOX9",basis="pca",color_exp="k", alpha_expr=0.1, size_expr=.01,fitted_linewidth=5,)
scf.pl.single_trend(GW_mini,"OLIG1",basis="pca",color_exp="k", alpha_expr=0.1, size_expr=.01,fitted_linewidth=5,)
scf.pl.single_trend(GW_mini,"OLIG2",basis="pca",color_exp="k", alpha_expr=0.1, size_expr=.01,fitted_linewidth=5,)

# %%
scf.pl.single_trend(GW_mini,"SOX2",basis="pca",color_exp="k", alpha_expr=0.1, size_expr=.01,fitted_linewidth=5,)

# %%
scf.pl.single_trend(GW_mini,"NOTCH1",basis="pca",color_exp="k", alpha_expr=0.1, size_expr=.01,fitted_linewidth=5,)

# %%
scf.pl.single_trend(GW_mini,"ASCL1",basis="pca",color_exp="k", alpha_expr=0.1, size_expr=.01,fitted_linewidth=5,)

# %%
#scf.pl.single_trend(GW_mini,"DLX2",basis="pca",color_exp="k", alpha_expr=0.1, size_expr=.01,fitted_linewidth=5,)
scf.pl.single_trend(GW_mini,"DLX5",basis="pca",color_exp="k", alpha_expr=0.1, size_expr=.01,fitted_linewidth=5,)
scf.pl.single_trend(GW_mini,"DLX6",basis="pca",color_exp="k", alpha_expr=0.1, size_expr=.01,fitted_linewidth=5,)

# %%
scf.tl.cluster(GW_mini, n_neighbors=100, metric="correlation")

# %%
GW_mini.var['clusters'] = GW_mini.var.clusters.astype('category')
GW_mini.obs['seg'] = GW_mini.obs.seg.astype('category')

# %%
GW_

# %%
for c in GW_mini.var["clusters"].unique():
    scf.pl.trends(GW_mini,features=GW_mini.var_names[GW_mini.var.clusters==c],basis="pca",feature_cmap='PuRd',
    pseudo_cmap = 'magma',)
